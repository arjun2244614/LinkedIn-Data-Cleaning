# %%
import pandas as pd

# %%
link=pd.read_csv("linkedin_dataframe.csv")

# %%
link.head(20)
# Out:
#                                       linkedinProfile                  mail  \
# 0   https://www.linkedin.com/in/eli-k-theard-03857...  elitheard2@gmail.com
# 1   https://www.linkedin.com/in/ahmed-abdelmonem-k...                   NaN
# 2   https://www.linkedin.com/in/allen-staines-058b...                   NaN
# 3             https://www.linkedin.com/in/mcaf-simha/                   NaN
# 4   https://www.linkedin.com/in/steven-johnson-624...                   NaN
# 5   https://www.linkedin.com/in/ary-yuliaryanto-41...                   NaN
# 6             https://www.linkedin.com/in/aaspiridis/                   NaN
# 7   https://www.linkedin.com/in/shahnawaz-b-3a4833...                   NaN
# 8             https://www.linkedin.com/in/7674021576/  mridhul380@gmail.com
# 9   https://www.linkedin.com/in/matthew-carpenter-...                   NaN
# 10  https://www.linkedin.com/in/wafaa-swity-8b913a...                   NaN
# ...

# %%
   
# making new data frame with dropped null values  
new_link = link.dropna(axis = 0, how ='any')  
print(len(new_link))
print(len(link))

#So every cloumn is having at least 1 null value, so we must handle the null values first
# Out:
# 0
# 1000

# %%
link.dtypes
link.columns
# Out:
# Index(['linkedinProfile', 'mail', 'description', 'location', 'imgUrl',
#        'firstName', 'lastName', 'fullName', 'subscribers', 'connectionDegree',
#        'vmid', 'linkedinSalesNavigatorUrl', 'connectionsCount',
#        'connectionsUrl', 'mutualConnectionsUrl', 'mutualConnectionsCount',
#        'company', 'companyUrl', 'jobTitle', 'jobLocation', 'jobDateRange',
#        'company2', 'companyUrl2', 'jobTitle2', 'jobDescription2',
#        'jobLocation2', 'jobDateRange2', 'school', 'schoolUrl', 'schoolDegree',
#        'schoolDescription', 'schoolDegreeSpec', 'schoolDateRange', 'school2',
#        'schoolUrl2', 'schoolDegree2', 'schoolDescription2',
#        'schoolDegreeSpec2', 'schoolDateRange2', 'websiteFromDropContact',
#        'birthday', 'companyWebsite', 'allSkills', 'skill1', 'endorsement1',
#        'skill2', 'endorsement2', 'skill3', 'endorsement3', 'skill4',
#        'endorsement4', 'skill5', 'endorsement5', 'skill6', 'endorsement6',
# ...

# %%
link.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 65 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   linkedinProfile            980 non-null    object
#  1   mail                       74 non-null     object
#  2   description                736 non-null    object
#  3   location                   979 non-null    object
#  4   imgUrl                     814 non-null    object
#  5   firstName                  980 non-null    object
#  6   lastName                   980 non-null    object
#  7   fullName                   980 non-null    object
#  8   subscribers                972 non-null    float64
#  9   connectionDegree           968 non-null    object
#  10  vmid                       978 non-null    object
#  11  linkedinSalesNavigatorUrl  978 non-null    object
#  12  connectionsCount           972 non-null    float64
# ...

# %%
# sum of all the columns having null values
link1=link.isnull().sum()
link1.head(60)
# Out:
# linkedinProfile               20
# mail                         926
# description                  264
# location                      21
# imgUrl                       186
# firstName                     20
# lastName                      20
# fullName                      20
# subscribers                   28
# connectionDegree              32
# vmid                          22
# linkedinSalesNavigatorUrl     22
# connectionsCount              28
# connectionsUrl                22
# mutualConnectionsUrl          22
# mutualConnectionsCount       962
# company                       52
# companyUrl                    48
# jobTitle                      48
# jobLocation                  247
# jobDateRange                  60
# company2                     153
# companyUrl2                  152
# jobTitle2                    152
# jobDescription2              515
# jobLocation2                 304
# jobDateRange2                157
# school                        73
# ...

# %%
link.columns
# Out:
# Index(['linkedinProfile', 'mail', 'description', 'location', 'imgUrl',
#        'firstName', 'lastName', 'fullName', 'subscribers', 'connectionDegree',
#        'vmid', 'linkedinSalesNavigatorUrl', 'connectionsCount',
#        'connectionsUrl', 'mutualConnectionsUrl', 'mutualConnectionsCount',
#        'company', 'companyUrl', 'jobTitle', 'jobLocation', 'jobDateRange',
#        'company2', 'companyUrl2', 'jobTitle2', 'jobDescription2',
#        'jobLocation2', 'jobDateRange2', 'school', 'schoolUrl', 'schoolDegree',
#        'schoolDescription', 'schoolDegreeSpec', 'schoolDateRange', 'school2',
#        'schoolUrl2', 'schoolDegree2', 'schoolDescription2',
#        'schoolDegreeSpec2', 'schoolDateRange2', 'websiteFromDropContact',
#        'birthday', 'companyWebsite', 'allSkills', 'skill1', 'endorsement1',
#        'skill2', 'endorsement2', 'skill3', 'endorsement3', 'skill4',
#        'endorsement4', 'skill5', 'endorsement5', 'skill6', 'endorsement6',
# ...

# %%
#I am not droping the Na values instead replacing it with some values


linkn=link.fillna({'linkedinProfile':'LinkNotAvailable', 'mail':'xyz@xyz.com', 'description':'NotAvailable', 'location':'NotGiven', 'imgUrl':'Notuploaded',
       'firstName':'NotFilled', 'lastName':'NotFilled', 'fullName':'NotFilled', 'subscribers':0, 'connectionDegree':'NoDegree',
       'vmid':'NoVmid', 'linkedinSalesNavigatorUrl':'NoSalesURL', 'connectionsCount':0,
       'connectionsUrl':'Noconnections', 'mutualConnectionsUrl':'NoMutualConnectionsUrl', 'mutualConnectionsCount':0,
       'company':'NoCompany', 'companyUrl':'NoCompanyUrl', 'jobTitle':'NoJob', 'jobLocation':'NoJob', 'jobDateRange':0,
       'company2':'NoCom', 'companyUrl':'NoCompanyUrl', 'jobTitle2':'NoJob', 'jobDescription2':'NoJob',
       'jobLocation2':'NoJob', 'jobDateRange2':0, 'school':'NotMentioned', 'schoolUrl':'NoSchoolUrl', 'schoolDegree':'NoDegree',
       'schoolDescription':'NoDescription', 'schoolDegreeSpec':'NoSchoolSpec', 'schoolDateRange':0, 'school2':'NoSchool',
       'schoolUrl2':'NoSchoolUrl', 'schoolDegree2':'NoDegree', 'schoolDescription2':'NoDescription',
       'schoolDegreeSpec2':'NoDegreeSpec', 'schoolDateRange2':0, 'websiteFromDropContact':'NotMentioned',
       'birthday':'NotEntered', 'companyWebsite':'NoCompanyWebsite', 'allSkills':'NoSkills', 'skill1':'NoSkill', 'endorsement1':0,
       'skill2':'NoSkill', 'endorsement2':0, 'skill3':'NoSkill', 'endorsement3':0, 'skill4':'NoSkill',
       'endorsement4':0, 'skill5':'NoSkill', 'endorsement5':0, 'skill6':'NoSkill', 'endorsement6':0,
       'baseUrl':'NobaseURL', 'profileId':'NotProfiled', 'timestamp':'NotAvailable', 'jobDescription':'NoJob',
       'civilityFromDropContact':'NoContact', 'website':'NoWebsite', 'mailFromDropcontact':'Nomailid', 'twitter':'TwitterNotLinked',
       'facebookUrl':'facebookNotLinked', 'headline':'NoHeadline'})

# %%
#So now there is no null values in data frame. If required i could have removed the cloumns which are not important but 
#for now i not droping any data instead filled the missing values.
linkn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 65 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   linkedinProfile            1000 non-null   object
#  1   mail                       1000 non-null   object
#  2   description                1000 non-null   object
#  3   location                   1000 non-null   object
#  4   imgUrl                     1000 non-null   object
#  5   firstName                  1000 non-null   object
#  6   lastName                   1000 non-null   object
#  7   fullName                   1000 non-null   object
#  8   subscribers                1000 non-null   float64
#  9   connectionDegree           1000 non-null   object
#  10  vmid                       1000 non-null   object
#  11  linkedinSalesNavigatorUrl  1000 non-null   object
#  12  connectionsCount           1000 non-null   float64
# ...

# %%
linkn.head(10)
# Out:
#                                      linkedinProfile                  mail  \
# 0  https://www.linkedin.com/in/eli-k-theard-03857...  elitheard2@gmail.com
# 1  https://www.linkedin.com/in/ahmed-abdelmonem-k...           xyz@xyz.com
# 2  https://www.linkedin.com/in/allen-staines-058b...           xyz@xyz.com
# 3            https://www.linkedin.com/in/mcaf-simha/           xyz@xyz.com
# 4  https://www.linkedin.com/in/steven-johnson-624...           xyz@xyz.com
# 5  https://www.linkedin.com/in/ary-yuliaryanto-41...           xyz@xyz.com
# 6            https://www.linkedin.com/in/aaspiridis/           xyz@xyz.com
# 7  https://www.linkedin.com/in/shahnawaz-b-3a4833...           xyz@xyz.com
# 8            https://www.linkedin.com/in/7674021576/  mridhul380@gmail.com
# 9  https://www.linkedin.com/in/matthew-carpenter-...           xyz@xyz.com
#
#                                          description  \
# 0  New work mobile \n406-203-8478\n\nWant to meet...
# ...

# %%
linkn.describe()
# Out:
#         subscribers  connectionsCount  mutualConnectionsCount  endorsement1  \
# count   1000.000000       1000.000000             1000.000000   1000.000000
# mean    1510.051000        311.086000                0.103000     11.543000
# std     3936.269612        189.562492                1.732453     21.376134
# min        0.000000          0.000000                0.000000      0.000000
# 25%      121.000000        117.750000                0.000000      0.000000
# 50%      351.500000        351.500000                0.000000      3.000000
# 75%     1014.250000        500.000000                0.000000     12.000000
# max    46703.000000        500.000000               54.000000     99.000000
#
#        endorsement3  endorsement4  endorsement5  endorsement6
# count   1000.000000   1000.000000   1000.000000   1000.000000
# mean       8.304000      6.533000      5.705000      5.122000
# std       18.033102     15.319974     14.283066     13.601254
# ...

# %%
linkn.columns
# Out:
# Index(['linkedinProfile', 'mail', 'description', 'location', 'imgUrl',
#        'firstName', 'lastName', 'fullName', 'subscribers', 'connectionDegree',
#        'vmid', 'linkedinSalesNavigatorUrl', 'connectionsCount',
#        'connectionsUrl', 'mutualConnectionsUrl', 'mutualConnectionsCount',
#        'company', 'companyUrl', 'jobTitle', 'jobLocation', 'jobDateRange',
#        'company2', 'companyUrl2', 'jobTitle2', 'jobDescription2',
#        'jobLocation2', 'jobDateRange2', 'school', 'schoolUrl', 'schoolDegree',
#        'schoolDescription', 'schoolDegreeSpec', 'schoolDateRange', 'school2',
#        'schoolUrl2', 'schoolDegree2', 'schoolDescription2',
#        'schoolDegreeSpec2', 'schoolDateRange2', 'websiteFromDropContact',
#        'birthday', 'companyWebsite', 'allSkills', 'skill1', 'endorsement1',
#        'skill2', 'endorsement2', 'skill3', 'endorsement3', 'skill4',
#        'endorsement4', 'skill5', 'endorsement5', 'skill6', 'endorsement6',
# ...

# %%
linkn.dtypes
# Out:
# linkedinProfile        object
# mail                   object
# description            object
# location               object
# imgUrl                 object
#                         ...
# website                object
# mailFromDropcontact    object
# twitter                object
# facebookUrl            object
# headline               object
# Length: 65, dtype: object

# %%
linkn.set_index('linkedinProfile',inplace=True)

# %%
#we can pull out the information of particular profile using linkedin web address
linkn.loc['https://www.linkedin.com/in/mcaf-simha/'].head(10)
# Out:
# mail                                                      xyz@xyz.com
# description         Experienced Professional Service Consultant - ...
# location            Orange County y alrededores, California, Estad...
# imgUrl                                                    Notuploaded
# firstName                                                     Pradeep
# lastName                                                        Simha
# fullName                                                Pradeep Simha
# subscribers                                                      3027
# connectionDegree                                                  3rd
# vmid                          ACoAABcELaQBWIPV9lRtCQt8r6VaVlXVDMbhaPg
# Name: https://www.linkedin.com/in/mcaf-simha/, dtype: object

# %%
#filtering the profiles having connection counts less than eaqual to 100
cc=linkn['connectionsCount']<=100
linkn[cc]
# Out:
#                                                            mail  \
# linkedinProfile
# https://www.linkedin.com/in/steven-johnson-6242...  xyz@xyz.com
# https://www.linkedin.com/in/matthew-carpenter-4...  xyz@xyz.com
# https://www.linkedin.com/in/khrystyna-sosiak-34...  xyz@xyz.com
# https://www.linkedin.com/in/rashmi-sharma-a2a82...  xyz@xyz.com
# LinkNotAvailable                                    xyz@xyz.com
# ...                                                         ...
# https://www.linkedin.com/in/lucindaosullivan/       xyz@xyz.com
# https://www.linkedin.com/in/brady-green-bpg14/      xyz@xyz.com
# LinkNotAvailable                                    xyz@xyz.com
# https://www.linkedin.com/in/nikhil-kishan-4aab0...  xyz@xyz.com
# https://www.linkedin.com/in/chenli92/               xyz@xyz.com
#
#                                                                                           description  \
# linkedinProfile
# ...

# %%
#filtering the profiles having less than equal to 100 connections and their location
linkn.loc[cc,'location']
# Out:
# linkedinProfile
# https://www.linkedin.com/in/steven-johnson-624294163/                          Saltillo y alrededores, México
# https://www.linkedin.com/in/matthew-carpenter-47a9b6110/                                 Broomfield, Colorado
# https://www.linkedin.com/in/khrystyna-sosiak-345119176/                Cracow, Lesser Poland District, Poland
# https://www.linkedin.com/in/rashmi-sharma-a2a821106/                                  New Delhi, Delhi, India
# LinkNotAvailable                                                                                     NotGiven
#                                                                                   ...
# https://www.linkedin.com/in/lucindaosullivan/                                                       Australia
# https://www.linkedin.com/in/brady-green-bpg14/              Burlington y alrededores, Vermont, Estados Unidos
# ...

# %%
#Profiles with 500 or more connections with their name,company,skills,job, social media links
Highconcount=(linkn['connectionsCount'])>=500
linkn.loc[Highconcount,['fullName','company','allSkills','jobDescription','twitter','facebookUrl']]
# Out:
#                                                                   fullName  \
# linkedinProfile
# https://www.linkedin.com/in/eli-k-theard-038571...           Eli K. Theard
# https://www.linkedin.com/in/ahmed-abdelmonem-ka...  Ahmed Abdelmonem Kamal
# https://www.linkedin.com/in/allen-staines-058b0...           Allen Staines
# https://www.linkedin.com/in/mcaf-simha/                      Pradeep Simha
# https://www.linkedin.com/in/ary-yuliaryanto-417...         ARY Yuliaryanto
# ...                                                                    ...
# https://www.linkedin.com/in/mytrapham/                    My Tra Pham, CMA
# https://www.linkedin.com/in/tom-rons/                             Tom Rons
# https://www.linkedin.com/in/qiong-wei-9100b420/                  Qiong Wei
# https://www.linkedin.com/in/davidsspencer/                   David Spencer
# https://www.linkedin.com/in/john-nwokeji/                  Uchenna Nwokeji
#
# ...

# %%
linkn.describe()
# Out:
#         subscribers  connectionsCount  mutualConnectionsCount  endorsement1  \
# count   1000.000000       1000.000000             1000.000000   1000.000000
# mean    1510.051000        311.086000                0.103000     11.543000
# std     3936.269612        189.562492                1.732453     21.376134
# min        0.000000          0.000000                0.000000      0.000000
# 25%      121.000000        117.750000                0.000000      0.000000
# 50%      351.500000        351.500000                0.000000      3.000000
# 75%     1014.250000        500.000000                0.000000     12.000000
# max    46703.000000        500.000000               54.000000     99.000000
#
#        endorsement3  endorsement4  endorsement5  endorsement6
# count   1000.000000   1000.000000   1000.000000   1000.000000
# mean       8.304000      6.533000      5.705000      5.122000
# std       18.033102     15.319974     14.283066     13.601254
# ...

# %%
#Returns the count of the company
link['company'].value_counts()
# Out:
# Self-employed                  5
# Self-Employed                  3
# IBM                            3
# Self Employed                  3
# Confidential                   3
#                               ..
# Astegic                        1
# RETAIL FOOD GROUP AUSTRALIA    1
# Vodafone Idea Limited          1
# Iran Aircraft Industries       1
# Aam Aadmi Party                1
# Name: company, Length: 909, dtype: int64

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.hist(linkn.endorsement1,bins=6)
# Out:
# (array([809.,  95.,  32.,  16.,  14.,  34.]),
#  array([ 0. , 16.5, 33. , 49.5, 66. , 82.5, 99. ]),
#  <a list of 6 Patch objects>)

# %%
linkn[(linkn.skill1=='Business Analysis')].endorsement1
# Out:
# linkedinProfile
# https://www.linkedin.com/in/omid-hossein-pour-1739b315b/           1.0
# https://www.linkedin.com/in/karol-kamil-piekarz-72429729/         21.0
# https://www.linkedin.com/in/thulani-gom-11ba4973/                  5.0
# https://www.linkedin.com/in/daniel-dubin-csm-ms-is-b278938/       35.0
# https://www.linkedin.com/in/rita-caruso-43928b52/                  3.0
# https://www.linkedin.com/in/seanfiynn/                            71.0
# https://www.linkedin.com/in/sachin-manchanda-63969b3/             99.0
# https://www.linkedin.com/in/yukiko-anderson-92b36162/              0.0
# https://www.linkedin.com/in/rohit-raj-6b930854/                    1.0
# https://www.linkedin.com/in/sharath-r-b63108107/                   0.0
# https://www.linkedin.com/in/dimitris-chondrogiannis-199a97158/     5.0
# https://www.linkedin.com/in/jose-alanis-03456835/                 20.0
# Name: endorsement1, dtype: float64

# %%
plt.hist(linkn[(linkn.skill1=='Business Analysis')].endorsement1)
# Out:
# (array([7., 0., 2., 1., 0., 0., 0., 1., 0., 1.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist([linkn[linkn.skill1=='Business Analysis'].endorsement1,linkn[linkn.skill1=='Data Analysis'].endorsement1,linkn[linkn.skill1=='SQL'].endorsement1])
# Out:
# ([array([7., 0., 2., 1., 0., 0., 0., 1., 0., 1.]),
#   array([30.,  2.,  3.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]),
#   array([10.,  4.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.])],
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <a list of 3 Lists of Patches objects>)

# %%
b=sns.barplot(data=linkn,x='mutualConnectionsCount',y='endorsement5')
b.tick_params(labelsize=10)

# %%
linkn.describe(include='all')
# Out:
#                mail   description                location       imgUrl  \
# count          1000          1000                    1000         1000
# unique           75           734                     500          815
# top     xyz@xyz.com  NotAvailable  Emiratos Árabes Unidos  Notuploaded
# freq            926           264                      30          186
# mean            NaN           NaN                     NaN          NaN
# std             NaN           NaN                     NaN          NaN
# min             NaN           NaN                     NaN          NaN
# 25%             NaN           NaN                     NaN          NaN
# 50%             NaN           NaN                     NaN          NaN
# 75%             NaN           NaN                     NaN          NaN
# max             NaN           NaN                     NaN          NaN
#
#         firstName   lastName   fullName   subscribers connectionDegree  \
# ...
